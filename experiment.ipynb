# %%
import PyPDF2
import pytesseract
import pypdfium2 as pdfium
from pathlib import Path
import re
from typing import Dict, List, Optional

# %%
def perform_ocr_on_pdf(pdf_path: Path, dpi: int = 300, tesseract_cmd = None) -> str:
    if tesseract_cmd:
        pytesseract.pytesseract.tesseract_cmd = tesseract_cmd
        
    pdf = pdfium.PdfDocument(str(pdf_path))
    text_pages = []
    scale = int(dpi / 72)

    for page in pdf:
        bitmap = page.render(scale = scale)
        img = bitmap.to_pil()
        text_pages.append(pytesseract.image_to_string(img, config='--psm 6'))

    return '\n'.join(text_pages)

def read_pdf_text(pdf_path: Path) -> str:
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
    if not text.strip():
        text = perform_ocr_on_pdf(pdf_path, tesseract_cmd=r"C:\Users\moazzam\AppData\Local\Programs\Tesseract-OCR\tesseract.exe")
        
    return text

# %%
pdfs_text = []
pdf_directory = Path(r"data\soap_notes")

for pdf in pdf_directory.glob("*.pdf"):
    pdf_text = read_pdf_text(pdf)
    pdfs_text.append({
        "file_name": pdf.name,
        "text": pdf_text
    })

# %%
print(pdfs_text[0]["text"])
# Out:
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 1/26/2026
# . ; GUTIB, Gion
# : Wy children’s
# ad medical group
# 01/26/2026 ProgressNotes: Humeraa Qamar, MD
# Current Medications Reason for Appointment
# Not-Taking ; 1. 9 month wellness, possible vaccines
# * Mometasone Furoate 0.1% Ointment 1 2. Breastfeed every 4-5 hrs and eating puree and solids foods 2-3 times a
# application Externally twice a day day
# 3. Well Child Examination - EPSDT - 9 months
# Screening
# History of Present Illness
# Review of Systems Interval History:
# General/Constitutional: Lives with: parents . Family support: yes, partner involved with care
# Ophthulmolaeie . Concerns/Questions: none . Primary care giver: mother . Interim
# “Discharge denies. Vision screen fixes and Illness: none . Sleep: sleeps through the night , () hours per night , ()
# follows, parent reports no concern. hours nap time during the day , no problems reported . Sees/Hears: well -
# ENT: as reported by parent , eyes straight always . Vaccine reactions: none
# Hearing screen responds to sounds, parent Emergency room visits: none
# reports no concern. a ° .
# Respiratory: Nutrition:
# Breathing pattern normal pattern, no Formula feeding: feeds adequately , () ounces every () hours , uses
# cat enee. Cough denies. bottled water to mix formula , milk based formula with iron - ()
# ~~ Constipation denies. . Diet: feeds solid food with no problems , fruit juices - () ounces per day ,
# Skin: 2-3 varieties of solid food , start cup for water/juice . Feeding
# Rash denies. problems: none reported . Fluoride supplement: no , uses tap water for
# all purposes . Food allergies: none . Stool (bowel movement): regular
# with normal consistency . Vitamins/health supplements: none . Voiding
# (urine): well .
# Developmental Assessment:
# Personal - Social plays pat-a-cake , looks for fallen object. Fine Motor -
# Adaptive bangs two cubes held in hands , thumb - finger grasp
# . Language dada or mama - specific . Gross Motor Functions walks
# holding on , crawls , stands momentarily .
# Key Family Checks:
# Parents health/rest: good , no new health problems . Child care /day
# care: not used . Family support system good support system , extended
# family involved , father of baby with family and involved . Mother
# returned to: work . Concerns for abuse/neglect: none . Substance abuse
# in the family: none . Lead risk factors: none per history . Regular
# schedule: yes . Financial support: good , both parents work . Family
# planning: continue to use birth control methods . Parents agree on
# discipline: yes. Sibling rivalry: not applicable . Family change: none .
# Vital Signs
# Temp: 97.9 F, Wt: 20.14 lbs, BMI: 17.43 Index, Ht: 28.5 in, HC: 18.75
# in, Wt %: 57.14 %, Ht %: 52.04 %, HC in: 97.8 in.
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
#
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 01/26/2026
# Examination
# GENERAL APPEARANCE: alert, well nourished.
# HEAD: normocephalic, with anterior fontanelle open, atraumatic.
# EYES: normal.
# EARS: tympanic membrane intact, clear, BOTH EARS, auditory canal
# clear, BOTH EARS.
# NOSE: nares patent.
# ORAL CAVITY: mucosa moist, no lesions, palate normal.
# THROAT: normal.
# NECK/THYROID: neck supple, full range of motion.
# SKIN: normal, no suspicious lesions, sacttered dry skin..
# HEART: regular rate and rhythm, S1, S2 normal, no murmurs.
# LUNGS: clear to auscultation bilaterally.
# CHEST: normal shape and expansion.
# ABDOMEN: soft, nontender, nondistended, bowel sounds present,
# normal.
# BACK: normal exam of spine.
# EXTREMITIES: normal hip exam with no clicks, full range of motion.
# PERIPHERAL PULSES: normal.
# NEUROLOGIC: normal strength, tone and reflexes.
# Assessments
# 1. Encounter for routine child health examination without abnormal
# findings - Zoo0.129 (Primary)
# Treatment
# 1. Others
# Notes: age appropriate safety, feeding and sleeping care DW,
# Immunization
# ¢ flucelvax PFS 25/26 : 0.5 mL (Dose No:2) (Route: Intramuscular) given
# by Joyce Laguna Collazo , MA on Right Deltoid
# Preventive Medicine
# Handouts Given:
# Book given (reading program) . Fever control tylenol dosing handout
# given , motrin dosing handout given. Nutrition/Development . Parenting
# tips .
# Health Promotion:
# Assess lead risk . Oral health never put infant to bed with the bottle in the
# mouth , brush teeth - small amount of flouride toothpaste. Smoke
# exposure .
# Immunizations:
# Influenza . Rotavirus oral vaccine . PCV (pneumococcal) . Polio (IPV) .
# Injury Prevention/Safety:
# Appropriate car seat . Child proof home . Hot water safety (<125 degrees
# F) . Install and/or check smoke alarms regularly . No baby
# walker . Poison control Telephone number 1800 222 1222. Water safety .
# Nutrition Counseling:
# Appropriate frequency and duration of feedings discussed . Drink from
# cup . Never put infant to bed with the bottle in the mouth . Supervise
# eating .
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
#
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 01/26/2026
# Social/Behavioral Counseling:
# Bedtime routine . Discipline . Family planning . Opportunity to
# explore . Play group . Stranger anxiety . Time for self and partner .
# Violence Prevention:
# Never shake baby .
# Vaccine information sheets given - Date on VIS verified
# I performed vaccine counseling with the parent on risks and benefits
# for all vaccine components. (Risks and benefits discussed include but
# not limited to: swelling, safe outcomes based on well performed studies,
# no preservatives, etc.).
# Follow Up
# 4 Weeks weight check
# Care Plan Details
# ee
# Electronically signed by HUMERAA QAMAR, MD on 01/26/2026
# at 03:04 PM EST
# Sign off status: Completed
# CHILDREN'S MEDICAL GROUP
# 1749 SE 28TH LOOP
# OCALA, FL 34471-1079
# Tel: 352-369-8690
# Fax: 352-369-8693
# Progress Note: Humeraa Qamar, MD 01/26/2026
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST

# %%
# =========================
# Normalization
# =========================
def normalize_text(text: str) -> str:
    text = text.replace("\u2013", "-")
    text = text.replace("\xa0", " ")
    text = re.sub(r"[ ]{2,}", " ", text)
    text = re.sub(r"\n{2,}", "\n", text)
    return text.strip()


# =========================
# Section Extractor
# =========================
def extract_section(text: str, start: str, stops: List[str]) -> Optional[str]:
    stop_pattern = "|".join(map(re.escape, stops))
    pattern = rf"{start}(.+?)(?:{stop_pattern}|$)"
    m = re.search(pattern, text, re.IGNORECASE | re.DOTALL)
    return m.group(1) if m else None


# =========================
# Generic helper
# =========================
def extract_single(pattern: str, text: str) -> Optional[str]:
    m = re.search(pattern, text, re.IGNORECASE | re.MULTILINE)
    return m.group(1).strip() if m else None


# =========================
# Extractors
# =========================
def extract_patient_name(text: str) -> Optional[str]:
    return extract_single(
        r"^([A-Z][A-Z\-']+,\s*[A-Z][A-Za-z\-']+(?:\s+[A-Z])?)(?=\s+DOB)",
        text
    )


def extract_dob(text: str) -> Optional[str]:
    dob = extract_single(
        r"DOB:\s*[@]?\s*(\d{1,2}/\d{1,2}/\d{4})",
        text
    )
    if not dob:
        return None

    try:
        m, d, y = map(int, dob.split("/"))
        if 1 <= m <= 12 and 1 <= d <= 31 and y >= 1900:
            return dob
    except ValueError:
        pass

    return None


def extract_age(text: str) -> Optional[str]:
    """
    Returns age WITH unit: e.g. '17 yo', '9 mo', '16 wo', '3 d'
    """
    m = re.search(
        r"\((\d+)\s*(yo|yrs?|mo|wo|days?|d)\b"
        r"|(\d+)\s*Y\s*old"
        r"|(\d+)\s*(days?|d)\s*old",
        text,
        re.IGNORECASE
    )
    if not m:
        return None

    if m.group(1):
        return f"{m.group(1)} {m.group(2)}"
    if m.group(3):
        return f"{m.group(3)} yo"
    if m.group(4):
        return f"{m.group(4)} {m.group(5)}"

    return None


def extract_dos(text: str) -> Optional[str]:
    return extract_single(
        r"DOS:\s*(\d{1,2}/\d{1,2}/\d{4})",
        text
    )


# =========================
# ICDs from Assessments only
# =========================
def extract_icd_codes(text: str) -> List[str]:
    assessments = extract_section(
        text,
        start="Assessments",
        stops=[
            "Treatment",
            "Procedure Codes",
            "Follow Up",
            "Care Plan",
            "Electronically signed"
        ]
    )

    if not assessments:
        return []

    icds = re.findall(
        r"\b[A-TV-Z][0-9]{2}(?:\.[0-9A-TV-Z]{1,4})?\b",
        assessments
    )
    return sorted(set(icds))


# =========================
# CPTs from Procedure Codes only
# =========================
def extract_cpt_codes(text: str) -> List[str]:
    procedures = extract_section(
        text,
        start="Procedure Codes",
        stops=[
            "Follow Up",
            "Care Plan",
            "Electronically signed",
            "Generated for Printing"
        ]
    )

    if not procedures:
        return []

    cpts = re.findall(r"\b(?:\d{5}|[A-Z]\d{4})\b", procedures)
    return sorted(set(cpts))


# =========================
# Consolidated
# =========================
def extract_demographics(text: str) -> Dict:
    text = normalize_text(text)
    return {
        "patient_name": extract_patient_name(text),
        "dob": extract_dob(text),
        "age": extract_age(text),
        "dos": extract_dos(text),
        "icd_codes": extract_icd_codes(text),
        "cpt_codes": extract_cpt_codes(text),
    }

# %%
all_data = []

for pdf in Path("data/soap_notes").rglob("*.pdf"):
    raw_text = read_pdf_text(pdf)
    normalized_text = normalize_text(raw_text)
    print(normalized_text)
    demographic = extract_demographics(normalized_text)
    all_data.append(demographic)
# Out:
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 1/26/2026
# . ; GUTIB, Gion
# : Wy children’s
# ad medical group
# 01/26/2026 ProgressNotes: Humeraa Qamar, MD
# Current Medications Reason for Appointment
# Not-Taking ; 1. 9 month wellness, possible vaccines
# * Mometasone Furoate 0.1% Ointment 1 2. Breastfeed every 4-5 hrs and eating puree and solids foods 2-3 times a
# application Externally twice a day day
# 3. Well Child Examination - EPSDT - 9 months
# Screening
# History of Present Illness
# Review of Systems Interval History:
# General/Constitutional: Lives with: parents . Family support: yes, partner involved with care
# Ophthulmolaeie . Concerns/Questions: none . Primary care giver: mother . Interim
# “Discharge denies. Vision screen fixes and Illness: none . Sleep: sleeps through the night , () hours per night , ()
# follows, parent reports no concern. hours nap time during the day , no problems reported . Sees/Hears: well -
# ENT: as reported by parent , eyes straight always . Vaccine reactions: none
# Hearing screen responds to sounds, parent Emergency room visits: none
# reports no concern. a ° .
# Respiratory: Nutrition:
# Breathing pattern normal pattern, no Formula feeding: feeds adequately , () ounces every () hours , uses
# cat enee. Cough denies. bottled water to mix formula , milk based formula with iron - ()
# ~~ Constipation denies. . Diet: feeds solid food with no problems , fruit juices - () ounces per day ,
# Skin: 2-3 varieties of solid food , start cup for water/juice . Feeding
# Rash denies. problems: none reported . Fluoride supplement: no , uses tap water for
# all purposes . Food allergies: none . Stool (bowel movement): regular
# with normal consistency . Vitamins/health supplements: none . Voiding
# (urine): well .
# Developmental Assessment:
# Personal - Social plays pat-a-cake , looks for fallen object. Fine Motor -
# Adaptive bangs two cubes held in hands , thumb - finger grasp
# . Language dada or mama - specific . Gross Motor Functions walks
# holding on , crawls , stands momentarily .
# Key Family Checks:
# Parents health/rest: good , no new health problems . Child care /day
# care: not used . Family support system good support system , extended
# family involved , father of baby with family and involved . Mother
# returned to: work . Concerns for abuse/neglect: none . Substance abuse
# in the family: none . Lead risk factors: none per history . Regular
# schedule: yes . Financial support: good , both parents work . Family
# planning: continue to use birth control methods . Parents agree on
# discipline: yes. Sibling rivalry: not applicable . Family change: none .
# Vital Signs
# Temp: 97.9 F, Wt: 20.14 lbs, BMI: 17.43 Index, Ht: 28.5 in, HC: 18.75
# in, Wt %: 57.14 %, Ht %: 52.04 %, HC in: 97.8 in.
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 01/26/2026
# Examination
# GENERAL APPEARANCE: alert, well nourished.
# HEAD: normocephalic, with anterior fontanelle open, atraumatic.
# EYES: normal.
# EARS: tympanic membrane intact, clear, BOTH EARS, auditory canal
# clear, BOTH EARS.
# NOSE: nares patent.
# ORAL CAVITY: mucosa moist, no lesions, palate normal.
# THROAT: normal.
# NECK/THYROID: neck supple, full range of motion.
# SKIN: normal, no suspicious lesions, sacttered dry skin..
# HEART: regular rate and rhythm, S1, S2 normal, no murmurs.
# LUNGS: clear to auscultation bilaterally.
# CHEST: normal shape and expansion.
# ABDOMEN: soft, nontender, nondistended, bowel sounds present,
# normal.
# BACK: normal exam of spine.
# EXTREMITIES: normal hip exam with no clicks, full range of motion.
# PERIPHERAL PULSES: normal.
# NEUROLOGIC: normal strength, tone and reflexes.
# Assessments
# 1. Encounter for routine child health examination without abnormal
# findings - Zoo0.129 (Primary)
# Treatment
# 1. Others
# Notes: age appropriate safety, feeding and sleeping care DW,
# Immunization
# ¢ flucelvax PFS 25/26 : 0.5 mL (Dose No:2) (Route: Intramuscular) given
# by Joyce Laguna Collazo , MA on Right Deltoid
# Preventive Medicine
# Handouts Given:
# Book given (reading program) . Fever control tylenol dosing handout
# given , motrin dosing handout given. Nutrition/Development . Parenting
# tips .
# Health Promotion:
# Assess lead risk . Oral health never put infant to bed with the bottle in the
# mouth , brush teeth - small amount of flouride toothpaste. Smoke
# exposure .
# Immunizations:
# Influenza . Rotavirus oral vaccine . PCV (pneumococcal) . Polio (IPV) .
# Injury Prevention/Safety:
# Appropriate car seat . Child proof home . Hot water safety (<125 degrees
# F) . Install and/or check smoke alarms regularly . No baby
# walker . Poison control Telephone number 1800 222 1222. Water safety .
# Nutrition Counseling:
# Appropriate frequency and duration of feedings discussed . Drink from
# cup . Never put infant to bed with the bottle in the mouth . Supervise
# eating .
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GUTIB, Gion DOB: 04/19/2025 (9 mo M) Acc No. 23565 DOS: 01/26/2026
# Social/Behavioral Counseling:
# Bedtime routine . Discipline . Family planning . Opportunity to
# explore . Play group . Stranger anxiety . Time for self and partner .
# Violence Prevention:
# Never shake baby .
# Vaccine information sheets given - Date on VIS verified
# I performed vaccine counseling with the parent on risks and benefits
# for all vaccine components. (Risks and benefits discussed include but
# not limited to: swelling, safe outcomes based on well performed studies,
# no preservatives, etc.).
# Follow Up
# 4 Weeks weight check
# Care Plan Details
# ee
# Electronically signed by HUMERAA QAMAR, MD on 01/26/2026
# at 03:04 PM EST
# Sign off status: Completed
# CHILDREN'S MEDICAL GROUP
# 1749 SE 28TH LOOP
# OCALA, FL 34471-1079
# Tel: 352-369-8690
# Fax: 352-369-8693
# Progress Note: Humeraa Qamar, MD 01/26/2026
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
# 2/3/26, 8:10 PM eCW (Mehmood, Mudasar )
# GRIESMEYER, Gunner DOB: 09/30/2025 (16 wo M) Acc No. 23791 DOS: 01/26/2026
# @ GRIESMEYER, Gunner
#  ) 8 bd ) 3M 26D old Male, DOB: 09/30/2025
# & | ren S Account Number: 23791
# 3 9 : 13880 SW 45TH TER, OCALA, FL-34473-2533
# Home: 321-960-1036
# oh, medica group Guarantor: Griesmeyer, Gunner Insurance: Tricare East -
# Humana Military Tricare - Payer ID: 99727
# Appointment Facility: CHILDREN'S MEDICAL GROUP
# 01/26/2026 ProgressNotes: Humeraa Qamar, MD
# - Reason for Appointment
# Screening
# 1. Concerned
# 2. Father stated patient has not been able to evacuate in 4 days, baby is
# more irritated than usual and is just breastfeeding as often
# History of Present Illness
# Constitutional:
# has not pooped x 4 days, mom is BF q 3 hours, does not seem
# uncomfortable. acting fine.
# Vital Signs
# Temp: 98.0 F, Wt: 12.12 Ibs, BMI: 14.19 Index, Ht: 24.50 in, HC: 15.50
# in, Wt %: 2.37 %, Ht %: 26.11 %, HC in: 3.82 in.
# Examination
# General Examination:
# GENERAL APPEARANCE: alert, well nourished.
# HEAD: normocephalic, with anterior fontanelle open, atraumatic.
# EYES: normal.
# EARS: tympanic membrane intact, clear, BOTH EARS, auditory canal
# clear, BOTH EARS.
# NOSE: nares patent.
# ORAL CAVITY: mucosa moist, no lesions, palate normal.
# THROAT: normal.
# NECK/THYROID: neck supple, full range of motion.
# SKIN: normal, no suspicious lesions.
# HEART: regular rate and rhythm, S1, S2 normal, no murmurs.
# LUNGS: clear to auscultation bilaterally.
# CHEST: normal shape and expansion.
# ABDOMEN: soft, nontender, nondistended, bowel sounds present,
# normal.
# BACK: normal exam of spine.
# EXTREMITIES: normal hip exam with no clicks, full range of motion.
# PERIPHERAL PULSES: normal.
# NEUROLOGIC: normal strength, tone and reflexes.
# Assessments
# 1. Constipation, unspecified - K59.00 (Primary)
# teaching> 30 mins,
# Progress Note: Humeraa Qamar, MD 01/26/2026
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:10 PM EST
# active (yes/no). School performance: average grades , no trouble with
# teachers , future plans/goals, no failures or repeats , no suspensions or
# excessive absenteism . Tuberculosis screening: no risks identified
# . Patients work: summer job .
# Vital Signs
# Temp: 97.8 F, HR: 94 /min, BP: 143/85 mm Hg, Wt: 206.0 lbs, BMI:
# 29.55 Index, Ht: 70 in, Vision: 20/20 (B), Wt %: 97.93 %, BMI %:
# 93.46 %, Ht %: 98.8 %.
# Examination
# General Examination:
# GENERAL APPEARANCE: alert, well nourished.
# HEAD: normocephalic, atraumatic.
# EYES: normal.
# EARS: tympanic membrane intact, clear, BOTH EARS, auditory canal
# clear, BOTH EARS.
# NOSE: nares patent.
# ORAL CAVITY: mucosa moist, no lesions, palate normal.
# THROAT: normal.
# NECK/THYROID: neck supple, full range of motion.
# SKIN: normal, no suspicious lesions.
# HEART: regular rate and rhythm, S1, S2 normal, no murmurs.
# LUNGS: clear to auscultation bilaterally.
# CHEST: normal shape and expansion.
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:07 PM EST
# 2/3/26, 8:08 PM eCW (Mehmood, Mudasar )
# GIBBS, Kayleigh DOB: 93/25/2007 (18 yo F) Acc No. 19518 DOS: 91/26/2026
# ABDOMEN: soft, nontender, nondistended, bowel sounds present,
# normal.
# BACK: normal exam of spine.
# FEMALE GENITOURINARY: normal.
# EXTREMITIES: normal hip exam with no clicks, full range of motion.
# PERIPHERAL PULSES: normal.
# NEUROLOGIC: normal strength, tone and reflexes.
# Assessments
# 1. Encounter for routine child health examination without abnormal
# findings - Zoo.129 (Primary) Notes : Mig-Ro-
# 2. Dietary counseling and surveillance - Z71.3 Notes : Mig-Ro-
# 3. Exercise counseling - Z71.82
# 4. Body mass index [BMT] pediatric, 85th percentile to less than 95th
# percentile for age - Z68.53
# Nutritional counseling > 15 min
# Treatment
# 1. Encounter for routine child health examination without
# abnormal findings
# LAB: Vitamin D, 1,25 Dihydroxy
# LAB: Renal Panel (10)
# LAB: Liver Function Test (LFT)
# LAB: Thyroid Panel With TSH
# LAB: Glucose
# LAB: Hemoglobin Aic
# LAB: CBC With Differential/Platelet
# LAB: Lipid Panel
# LAB: Hepatic Function Panel (7)
# LAB: Hemoglobin (Collection Date & Time - 01/26/2026)
# Immunization
# ¢ flucelvax PFS 25/26 : 0.5 mL (Dose No:6) (Route: Intramuscular) given
# by Joyce Laguna Collazo , MA on Right Deltoid
# Labs
# Lab: Hemoglobin (Collection Date & Time - 01/26/2026)
# Preventive Medicine
# Counseling:
# Communication to patient: Counseling for nutrition provided Yes no
# forced foods, family meals as often as possible, low fat choices, limit or
# eliminate junk food, adequate calcium, adequate iron containing
# foods, Counseling for physical activity provided Yes 60 minutes of
# physical activity daily as part of transportation, physical education, sport,
# free play and planned exercise. The activities should be a combination of
# moderate and vigorous intensity.
# Health Promotion:
# Oral health brush teeth - small amount of flouride toothpaste, dental
# appointment. Personal hygiene . Sexual health sexual development,
# * Albuterol Sulfate (2.5 MG/3ML) 0.083% 2. 2.5 mg of Semaglutide injection administered without complications in
# Nebulization Solution 3 mL as needed : - . . : : .
# Inhalation every 6 hrs periumbilical area. Sides effects, diet and physical exercise reviewed
# « Albuterol Sulfate HFA 108 (90 Base) and discussed with mom and patient. Verbalized understanding
# MCG/ACT Aerosol Solution 1-2 puff as . .
# needed Inhalation every 4 hrs As needed Vital Signs
# Not-Taking Temp: 97.4 F, HR: 78 /min, BP: 140/87 mm Hg, Wt: 229.3 Ibs, BMI:
# ¢ Ondansetron 4 MG Tablet Disintegrating 1 1.921 Ht: 623 %: 908.9 %. BMI %: 90.05 %. Ht %: 10.2 %.
# tablet on the tongue and allow to dissolve 41.93 Index, Ht: 62 in, Wt %: 98.9 %, 6: 99.05 7%, Ht 70: 19.3
# Orally Every 8 hours As needed Assessments
# ° tho ict daa thon wablet dalle fab tie 1. Body mass index [BMI] pediatric, greater than or equal to 95th
# Orally Once a day percentile for age - 268.54 (Primary)
# + predniSONE 20 MG Tablet 1 tablet Orally 2. Dietary counseling and surveillance - Z71.3
# Twice a day
# + Nebulizer System All-In-One - continue diet plan and proper exercise
# Miscellaneous as directed
# ¢ Omeprazole 20 MG Capsule Delayed
# Release 1 capsule 1/2 to 1 hour before Procedure Codes
# morning meal Orally Once a day
# ¢ 96372 THER/PROPH/DIAG INJ, SC/IM
# Screening Follow Up
# 1 Week
# Care Plan Details
# Electronically signed by HUMERAA QAMAR, MD on 01/26/2026
# at 12:12 PM EST
# Sign off status: Completed
# Progress Note: Humeraa Qamar, MD 01/26/2026
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:09 PM EST
# 2/3/26, 8:09 PM eCW (Mehmood, Mudasar )
# FLORES, Melanie S DOB: 93/18/2008 (17 yo F) Acc No. 23354 DOS: 01/26/2026
# CHILDREN'S MEDICAL GROUP
# 1749 SE 28TH LOOP
# OCALA, FL 34471-1079
# Tel: 352-369-8690
# Fax: 352-369-8693
# Progress Note: Humeraa Qamar, MD 01/26/2026
# Generated for Printing/Faxing/eTransmitting on: 02/03/2026 08:09 PM EST

# %%
all_data
# Out:
# [{'patient_name': 'GUTIB, Gion',
#   'dob': '04/19/2025',
#   'age': '9 mo',
#   'dos': '1/26/2026',
#   'icd_codes': [],
#   'cpt_codes': []},
#  {'patient_name': 'GRIESMEYER, Gunner',
#   'dob': '09/30/2025',
#   'age': '16 wo',
#   'dos': '01/26/2026',
#   'icd_codes': ['K59.00'],
#   'cpt_codes': []},
#  {'patient_name': 'GIBBS, Kayleigh',
#   'dob': None,
#   'age': '18 yo',
#   'dos': '01/26/2026',
#   'icd_codes': ['Z68.53', 'Z71.3', 'Z71.82'],
#   'cpt_codes': ['85018', '96127', '97802', 'G0447', 'G8510']},
#  {'patient_name': 'FLORES, Melanie S',
#   'dob': '03/18/2008',
#   'age': '17 yo',
#   'dos': '01/26/2026',
#   'icd_codes': ['Z71.3'],
#   'cpt_codes': ['96372']}]
